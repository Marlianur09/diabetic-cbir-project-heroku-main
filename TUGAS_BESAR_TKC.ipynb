# %% [markdown]
# <a href="https://colab.research.google.com/github/Marlianur09/diabetic-cbir-project-heroku-main/blob/main/TUGAS_BESAR_TKC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROJECT TEMU KEMBALI CITRA**
# * Muhammad Marlianur (201810370311023)
# * Ernowo Gordon Sukoco Utojo Unus (201810370311043)

# %% [markdown]
# # Import Library

# %%
# !pip install -q kaggle==1.5.8

# %%
# !pip install opendatasets

# %%
# !pip install --upgrade tensorflow

# %%
# !pip install opencv-python

# %%
# !pip install sklearn

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import random

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report, log_loss, accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# %% [markdown]
# # Load Dataset

# %% [markdown]
# Load dataset menggunakan username dan key kaggle berikut.
# * Username : "muhammadmarlianur"
# * Key : "81403f768f3dcbc9da268513b04c9ea1"

# %%
od.download("https://www.kaggle.com/c/aptos2019-blindness-detection")

# %%
train = pd.read_csv('aptos2019-blindness-detection/train.csv')
test = pd.read_csv('aptos2019-blindness-detection/test.csv')
submission= pd.read_csv('aptos2019-blindness-detection/sample_submission.csv')
train_dir = 'aptos2019-blindness-detection/train_images'

# %%
print('Number of train samples: ', train.shape[0])
print('Number of test samples: ', test.shape[0])
display(train.head())
# Out:
# Number of train samples:  3662
# Number of test samples:  1928
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %% [markdown]
# # PreProcessing Dataset

# %%
NoDR = train[train["diagnosis"] == 0]
NoDR.to_csv("Test/NoDR.csv")
NoDR.head()
# Out:
#          id_code  diagnosis
# 3   002c21358ce6          0
# 4   005b95c28852          0
# 6   0097f532ac9f          0
# 10  00cc2b75cddd          0
# 12  00f6c1be5a33          0

# %%
Mild = train[train["diagnosis"] == 1]
Mild.to_csv("Test/Mild.csv")
Mild.head()
# Out:
#          id_code  diagnosis
# 2   0024cdab0c1e          1
# 9   00cb6555d108          1
# 14  0124dffecf29          1
# 22  01b3aed3ed4c          1
# 45  0369f3efe69b          1

# %%
Moderate = train[train["diagnosis"] == 2]
Moderate.to_csv("Test/Moderate.csv")
Moderate.head()
# Out:
#          id_code  diagnosis
# 0   000c1434d8d7          2
# 7   00a8624548a9          2
# 8   00b74780d31d          2
# 11  00e4ddff966a          2
# 16  012a242ac6ff          2

# %%
Severe = train[train["diagnosis"] == 3]
Severe.to_csv("Test/Severe.csv")
Severe.head()
# Out:
#          id_code  diagnosis
# 13  0104b032c141          3
# 49  03c85870824c          3
# 56  042470a92154          3
# 74  05cd0178ccfe          3
# 81  069f43616fab          3

# %%
Proliferative_DR = train[train["diagnosis"] == 4]
Proliferative_DR.to_csv("Test/Proliferative_DR.csv")
Proliferative_DR.head()
# Out:
#          id_code  diagnosis
# 1   001639a390f0          4
# 5   0083ee8054ee          4
# 32  0243404e8a00          4
# 34  02685f13cefd          4
# 38  02dda30d3acf          4

# %%
train_0 = pd.read_csv('Test/NoDR.csv')
train_1 = pd.read_csv('Test/Mild.csv')
train_2 = pd.read_csv('Test/Moderate.csv')
train_3 = pd.read_csv('Test/Severe.csv')
train_4 = pd.read_csv('Test/Proliferative_DR.csv')

# %%
from random import shuffle

target_dir = 'Test/Gantinama'
shuffle(train_0['id_code'])
shuffle(train_1['id_code'])
shuffle(train_2['id_code'])
shuffle(train_3['id_code'])
shuffle(train_4['id_code'])


for i, img_name in enumerate(train_0['id_code']):
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    file_name = f"NoDR-{i + 1}.png"
    dest = os.path.join(target_dir, file_name)
    
    cv2.imwrite(dest, img)

for i, img_name in enumerate(train_1['id_code']):
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    file_name = f"Mild{i + 1}.png"
    dest = os.path.join(target_dir, file_name)
    
    cv2.imwrite(dest, img)

for i, img_name in enumerate(train_2['id_code']):
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    file_name = f"Moderate{i + 1}.png"
    dest = os.path.join(target_dir, file_name)
    
    cv2.imwrite(dest, img)

for i, img_name in enumerate(train_3['id_code']):
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    file_name = f"Severe{i + 1}.png"
    dest = os.path.join(target_dir, file_name)
    
    cv2.imwrite(dest, img)

for i, img_name in enumerate(train_4['id_code']):
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    file_name = f"Proliferative_DR{i + 1}.png"
    dest = os.path.join(target_dir, file_name)
    
    cv2.imwrite(dest, img)
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\random.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x[i], x[j] = x[j], x[i]

# %%
from pathlib import Path
from PIL import Image

inputPath = Path("Test/img")
inputFiles = inputPath.glob("**/*.png")
outputPath = Path("Test")
for f in inputFiles:
    outputFile = outputPath / Path(f.stem + ".jpg")
    im = Image.open(f)
    im.save(outputFile)

# %%
import seaborn as sns
import cv2
sns.set_style("white")
count = 1
plt.figure(figsize=[15, 15])
for img_name in train['id_code'][:10]:
    img = cv2.imread("aptos2019-blindness-detection/train_images/%s.png" % img_name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=2.0,
	  tileGridSize=(8, 8))
    equalized = cv2.equalizeHist(img)
    plt.subplot(5, 5, count)
    plt.imshow(equalized)
    plt.title("Image %s" % count)
    count += 1
    
plt.show()

# %%
train["id_code"] = train["id_code"].apply(lambda x: x + ".png")
test["id_code"] = test["id_code"].apply(lambda x: x + ".png")
train['diagnosis'] = train['diagnosis'].astype('str')
train.head()
# Out:
#             id_code diagnosis
# 0  000c1434d8d7.png         2
# 1  001639a390f0.png         4
# 2  0024cdab0c1e.png         1
# 3  002c21358ce6.png         0
# 4  005b95c28852.png         0

# %%
train_datagen=ImageDataGenerator(rescale=1./255, 
                                 validation_split=0.2,
                                 horizontal_flip=True)

train_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="aptos2019-blindness-detection/train_images/",
    x_col="id_code",
    y_col="diagnosis",
    batch_size=16,
    class_mode="categorical",
    target_size=(224, 224),
    subset='training',
    color_mode='rgb')
# Out:
# Found 2930 validated image filenames belonging to 5 classes.

# %%
valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train,
    directory="aptos2019-blindness-detection/train_images/",
    x_col="id_code",
    y_col="diagnosis",
    batch_size=16,
    class_mode="categorical",    
    target_size=(224, 224),
    subset='validation',
    color_mode='rgb')
# Out:
# Found 732 validated image filenames belonging to 5 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(  
        dataframe=test,
        directory = "aptos2019-blindness-detection/test_images/",
        x_col="id_code",
        target_size=(224, 224),
        batch_size=16,
        shuffle=False,
        class_mode=None)
# Out:
# Found 1928 validated image filenames.

# %% [markdown]
# # Training Model
# * Training model menggunakan model MobileNet

# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.layers import InputLayer, Activation, Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization, AveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input

# %%
base_model4 = MobileNet(input_shape=(224,224,3),include_top=False,weights="imagenet")

# %%
class Combin3:
  def build(base_model1,classes):
    headModel = base_model1.output
    headModel = Flatten(name="flatten")(headModel)
    headModel = Dense(128, activation='relu')(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(classes, activation='softmax')(headModel)
    return headModel

# %%
headModel4 = Combin3.build(base_model4, 5)
model5 =Model(inputs=base_model4.input, outputs=headModel4)

# %%
for layer in base_model4.layers:
  layer.trainable = False

# %%
model5.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 9,652,165
# Trainable params: 6,423,301
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.metrics import Precision, Recall
model5.compile(
    optimizer=Adam(lr=0.00001, decay= 0.001/20),
    loss ='categorical_crossentropy',
    metrics =['accuracy',
              tf.keras.metrics.Precision(name='precision'),
              tf.keras.metrics.Recall(name='recall')]
)
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
test3=model5.fit(
    train_generator,
     validation_data = valid_generator,
     epochs=100,
     steps_per_epoch= 50,
     batch_size=20

)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 147s 3s/step - loss: 1.5790 - accuracy: 0.5471 - precision: 0.5950 - recall: 0.5140 - val_loss: 0.9023 - val_accuracy: 0.6954 - val_precision: 0.7584 - val_recall: 0.5874
# Epoch 2/100
# 50/50 [==============================] - 139s 3s/step - loss: 1.0252 - accuracy: 0.6488 - precision: 0.7167 - recall: 0.5725 - val_loss: 0.8145 - val_accuracy: 0.7036 - val_precision: 0.8110 - val_recall: 0.6038
# Epoch 3/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.9368 - accuracy: 0.6762 - precision: 0.7602 - recall: 0.5825 - val_loss: 0.7732 - val_accuracy: 0.7391 - val_precision: 0.8173 - val_recall: 0.6052
# Epoch 4/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.8006 - accuracy: 0.7063 - precision: 0.7732 - recall: 0.6137 - val_loss: 0.7375 - val_accuracy: 0.7432 - val_precision: 0.8295 - val_recall: 0.6380
# Epoch 5/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.7580 - accuracy: 0.7325 - precision: 0.8153 - recall: 0.6400 - val_loss: 0.7324 - val_accuracy: 0.7473 - val_precision: 0.8360 - val_recall: 0.6339
# Epoch 6/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.7715 - accuracy: 0.7425 - precision: 0.8255 - recall: 0.6150 - val_loss: 0.7095 - val_accuracy: 0.7432 - val_precision: 0.8029 - val_recall: 0.6735
# Epoch 7/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.7251 - accuracy: 0.7412 - precision: 0.8160 - recall: 0.6650 - val_loss: 0.7219 - val_accuracy: 0.7363 - val_precision: 0.7870 - val_recall: 0.6612
# Epoch 8/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.7378 - accuracy: 0.7138 - precision: 0.7888 - recall: 0.6488 - val_loss: 0.6991 - val_accuracy: 0.7596 - val_precision: 0.8477 - val_recall: 0.6462
# Epoch 9/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.6654 - accuracy: 0.7634 - precision: 0.8551 - recall: 0.6832 - val_loss: 0.7037 - val_accuracy: 0.7582 - val_precision: 0.7952 - val_recall: 0.7213
# Epoch 10/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.7061 - accuracy: 0.7532 - precision: 0.8341 - recall: 0.6590 - val_loss: 0.6806 - val_accuracy: 0.7664 - val_precision: 0.8072 - val_recall: 0.7090
# Epoch 11/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.6830 - accuracy: 0.7506 - precision: 0.8328 - recall: 0.6845 - val_loss: 0.7145 - val_accuracy: 0.7445 - val_precision: 0.8368 - val_recall: 0.6516
# Epoch 12/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.6003 - accuracy: 0.7786 - precision: 0.8452 - recall: 0.6807 - val_loss: 0.6471 - val_accuracy: 0.7691 - val_precision: 0.8323 - val_recall: 0.7049
# Epoch 13/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.6610 - accuracy: 0.7588 - precision: 0.8424 - recall: 0.6612 - val_loss: 0.6602 - val_accuracy: 0.7596 - val_precision: 0.8582 - val_recall: 0.6448
# Epoch 14/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.6213 - accuracy: 0.7748 - precision: 0.8607 - recall: 0.6997 - val_loss: 0.6491 - val_accuracy: 0.7596 - val_precision: 0.8281 - val_recall: 0.6844
# Epoch 15/100
# 50/50 [==============================] - 136s 3s/step - loss: 0.5964 - accuracy: 0.7799 - precision: 0.8521 - recall: 0.7112 - val_loss: 0.6443 - val_accuracy: 0.7555 - val_precision: 0.8479 - val_recall: 0.6626
# Epoch 16/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.6470 - accuracy: 0.7513 - precision: 0.8234 - recall: 0.6762 - val_loss: 0.6494 - val_accuracy: 0.7568 - val_precision: 0.8425 - val_recall: 0.6503
# Epoch 17/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.5571 - accuracy: 0.8168 - precision: 0.8737 - recall: 0.7392 - val_loss: 0.6416 - val_accuracy: 0.7678 - val_precision: 0.8213 - val_recall: 0.7158
# Epoch 18/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.5747 - accuracy: 0.7975 - precision: 0.8542 - recall: 0.7175 - val_loss: 0.6311 - val_accuracy: 0.7719 - val_precision: 0.8393 - val_recall: 0.6995
# Epoch 19/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.5463 - accuracy: 0.8053 - precision: 0.8589 - recall: 0.7277 - val_loss: 0.6293 - val_accuracy: 0.7842 - val_precision: 0.8416 - val_recall: 0.7186
# Epoch 20/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.5872 - accuracy: 0.7912 - precision: 0.8650 - recall: 0.7050 - val_loss: 0.6379 - val_accuracy: 0.7773 - val_precision: 0.8293 - val_recall: 0.6967
# Epoch 21/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.5280 - accuracy: 0.8163 - precision: 0.8512 - recall: 0.7437 - val_loss: 0.6221 - val_accuracy: 0.7828 - val_precision: 0.8307 - val_recall: 0.7104
# Epoch 22/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.5297 - accuracy: 0.8112 - precision: 0.8622 - recall: 0.7588 - val_loss: 0.6148 - val_accuracy: 0.7842 - val_precision: 0.8293 - val_recall: 0.7432
# Epoch 23/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.5880 - accuracy: 0.7613 - precision: 0.8421 - recall: 0.7000 - val_loss: 0.6192 - val_accuracy: 0.7719 - val_precision: 0.8386 - val_recall: 0.6954
# Epoch 24/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.5109 - accuracy: 0.8150 - precision: 0.8710 - recall: 0.7425 - val_loss: 0.6096 - val_accuracy: 0.7883 - val_precision: 0.8537 - val_recall: 0.7254
# Epoch 25/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.4845 - accuracy: 0.8213 - precision: 0.8757 - recall: 0.7837 - val_loss: 0.6011 - val_accuracy: 0.7910 - val_precision: 0.8338 - val_recall: 0.7404
# Epoch 26/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.4713 - accuracy: 0.8300 - precision: 0.8822 - recall: 0.7675 - val_loss: 0.6208 - val_accuracy: 0.7801 - val_precision: 0.8144 - val_recall: 0.7432
# Epoch 27/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.4647 - accuracy: 0.8350 - precision: 0.8741 - recall: 0.7900 - val_loss: 0.6026 - val_accuracy: 0.7937 - val_precision: 0.8485 - val_recall: 0.7268
# Epoch 28/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.4900 - accuracy: 0.8138 - precision: 0.8810 - recall: 0.7588 - val_loss: 0.6382 - val_accuracy: 0.7855 - val_precision: 0.8331 - val_recall: 0.7090
# Epoch 29/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.4522 - accuracy: 0.8400 - precision: 0.8884 - recall: 0.7862 - val_loss: 0.6057 - val_accuracy: 0.7869 - val_precision: 0.8234 - val_recall: 0.7514
# Epoch 30/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.4594 - accuracy: 0.8400 - precision: 0.8870 - recall: 0.7850 - val_loss: 0.6088 - val_accuracy: 0.7828 - val_precision: 0.8297 - val_recall: 0.7322
# Epoch 31/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.4229 - accuracy: 0.8500 - precision: 0.8987 - recall: 0.7987 - val_loss: 0.5995 - val_accuracy: 0.7814 - val_precision: 0.8313 - val_recall: 0.7404
# Epoch 32/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.4325 - accuracy: 0.8388 - precision: 0.8925 - recall: 0.7987 - val_loss: 0.5955 - val_accuracy: 0.7896 - val_precision: 0.8308 - val_recall: 0.7377
# Epoch 33/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.4538 - accuracy: 0.8359 - precision: 0.8826 - recall: 0.7939 - val_loss: 0.5862 - val_accuracy: 0.7964 - val_precision: 0.8388 - val_recall: 0.7391
# Epoch 34/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.4262 - accuracy: 0.8425 - precision: 0.8787 - recall: 0.8062 - val_loss: 0.5945 - val_accuracy: 0.7951 - val_precision: 0.8457 - val_recall: 0.7336
# Epoch 35/100
# 50/50 [==============================] - 138s 3s/step - loss: 0.4419 - accuracy: 0.8562 - precision: 0.8933 - recall: 0.7990 - val_loss: 0.5834 - val_accuracy: 0.7992 - val_precision: 0.8343 - val_recall: 0.7568
# Epoch 36/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.4160 - accuracy: 0.8537 - precision: 0.8943 - recall: 0.8037 - val_loss: 0.5915 - val_accuracy: 0.7978 - val_precision: 0.8383 - val_recall: 0.7295
# Epoch 37/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.3885 - accuracy: 0.8675 - precision: 0.9120 - recall: 0.8288 - val_loss: 0.6028 - val_accuracy: 0.7964 - val_precision: 0.8438 - val_recall: 0.7309
# Epoch 38/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.3709 - accuracy: 0.8775 - precision: 0.9160 - recall: 0.8313 - val_loss: 0.5958 - val_accuracy: 0.7869 - val_precision: 0.8241 - val_recall: 0.7486
# Epoch 39/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.3917 - accuracy: 0.8750 - precision: 0.9157 - recall: 0.8288 - val_loss: 0.5873 - val_accuracy: 0.7992 - val_precision: 0.8240 - val_recall: 0.7609
# Epoch 40/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.3874 - accuracy: 0.8626 - precision: 0.9010 - recall: 0.8333 - val_loss: 0.5789 - val_accuracy: 0.7923 - val_precision: 0.8326 - val_recall: 0.7609
# Epoch 41/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.3894 - accuracy: 0.8512 - precision: 0.9079 - recall: 0.8012 - val_loss: 0.6073 - val_accuracy: 0.7978 - val_precision: 0.8255 - val_recall: 0.7432
# Epoch 42/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.3899 - accuracy: 0.8675 - precision: 0.9041 - recall: 0.8250 - val_loss: 0.5845 - val_accuracy: 0.7896 - val_precision: 0.8267 - val_recall: 0.7363
# Epoch 43/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.4091 - accuracy: 0.8600 - precision: 0.8945 - recall: 0.8163 - val_loss: 0.5805 - val_accuracy: 0.8046 - val_precision: 0.8481 - val_recall: 0.7705
# Epoch 44/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.3784 - accuracy: 0.8687 - precision: 0.8967 - recall: 0.8250 - val_loss: 0.5948 - val_accuracy: 0.7883 - val_precision: 0.8315 - val_recall: 0.7418
# Epoch 45/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.3436 - accuracy: 0.8825 - precision: 0.9058 - recall: 0.8537 - val_loss: 0.6039 - val_accuracy: 0.8033 - val_precision: 0.8326 - val_recall: 0.7609
# Epoch 46/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.3008 - accuracy: 0.8875 - precision: 0.9176 - recall: 0.8625 - val_loss: 0.6031 - val_accuracy: 0.7883 - val_precision: 0.8303 - val_recall: 0.7486
# Epoch 47/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.3652 - accuracy: 0.8712 - precision: 0.9081 - recall: 0.8275 - val_loss: 0.6020 - val_accuracy: 0.7923 - val_precision: 0.8231 - val_recall: 0.7500
# Epoch 48/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.3495 - accuracy: 0.8788 - precision: 0.9112 - recall: 0.8338 - val_loss: 0.5884 - val_accuracy: 0.7978 - val_precision: 0.8313 - val_recall: 0.7609
# Epoch 49/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.3304 - accuracy: 0.8728 - precision: 0.9134 - recall: 0.8321 - val_loss: 0.6299 - val_accuracy: 0.7883 - val_precision: 0.8087 - val_recall: 0.7623
# Epoch 50/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.3653 - accuracy: 0.8675 - precision: 0.9069 - recall: 0.8400 - val_loss: 0.5877 - val_accuracy: 0.8060 - val_precision: 0.8376 - val_recall: 0.7609
# Epoch 51/100
# 50/50 [==============================] - 148s 3s/step - loss: 0.3366 - accuracy: 0.8775 - precision: 0.9194 - recall: 0.8413 - val_loss: 0.5919 - val_accuracy: 0.7992 - val_precision: 0.8393 - val_recall: 0.7637
# Epoch 52/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.2637 - accuracy: 0.9000 - precision: 0.9224 - recall: 0.8763 - val_loss: 0.5932 - val_accuracy: 0.8019 - val_precision: 0.8324 - val_recall: 0.7732
# Epoch 53/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.3188 - accuracy: 0.8888 - precision: 0.9152 - recall: 0.8500 - val_loss: 0.6117 - val_accuracy: 0.7951 - val_precision: 0.8270 - val_recall: 0.7705
# Epoch 54/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.2914 - accuracy: 0.8931 - precision: 0.9098 - recall: 0.8601 - val_loss: 0.6009 - val_accuracy: 0.7992 - val_precision: 0.8365 - val_recall: 0.7760
# Epoch 55/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.3056 - accuracy: 0.8850 - precision: 0.9176 - recall: 0.8487 - val_loss: 0.6105 - val_accuracy: 0.8005 - val_precision: 0.8271 - val_recall: 0.7582
# Epoch 56/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.2993 - accuracy: 0.8969 - precision: 0.9180 - recall: 0.8550 - val_loss: 0.6119 - val_accuracy: 0.7910 - val_precision: 0.8258 - val_recall: 0.7705
# Epoch 57/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.3244 - accuracy: 0.8725 - precision: 0.9167 - recall: 0.8388 - val_loss: 0.5738 - val_accuracy: 0.8060 - val_precision: 0.8446 - val_recall: 0.7650
# Epoch 58/100
# 50/50 [==============================] - 146s 3s/step - loss: 0.3086 - accuracy: 0.9013 - precision: 0.9256 - recall: 0.8712 - val_loss: 0.5979 - val_accuracy: 0.7964 - val_precision: 0.8249 - val_recall: 0.7787
# Epoch 59/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.3097 - accuracy: 0.8850 - precision: 0.9128 - recall: 0.8637 - val_loss: 0.5734 - val_accuracy: 0.8060 - val_precision: 0.8431 - val_recall: 0.7637
# Epoch 60/100
# 50/50 [==============================] - 161s 3s/step - loss: 0.2926 - accuracy: 0.8900 - precision: 0.9209 - recall: 0.8587 - val_loss: 0.5885 - val_accuracy: 0.8169 - val_precision: 0.8410 - val_recall: 0.7732
# Epoch 61/100
# 50/50 [==============================] - 178s 4s/step - loss: 0.2730 - accuracy: 0.8963 - precision: 0.9260 - recall: 0.8763 - val_loss: 0.6168 - val_accuracy: 0.8033 - val_precision: 0.8353 - val_recall: 0.7760
# Epoch 62/100
# 50/50 [==============================] - 180s 4s/step - loss: 0.2493 - accuracy: 0.9200 - precision: 0.9429 - recall: 0.8875 - val_loss: 0.5959 - val_accuracy: 0.7992 - val_precision: 0.8294 - val_recall: 0.7773
# Epoch 63/100
# 50/50 [==============================] - 188s 4s/step - loss: 0.2400 - accuracy: 0.9150 - precision: 0.9319 - recall: 0.8900 - val_loss: 0.6217 - val_accuracy: 0.7978 - val_precision: 0.8306 - val_recall: 0.7705
# Epoch 64/100
# 50/50 [==============================] - 180s 4s/step - loss: 0.2858 - accuracy: 0.9020 - precision: 0.9229 - recall: 0.8830 - val_loss: 0.5928 - val_accuracy: 0.7951 - val_precision: 0.8341 - val_recall: 0.7623
# Epoch 65/100
# 50/50 [==============================] - 190s 4s/step - loss: 0.2688 - accuracy: 0.9100 - precision: 0.9392 - recall: 0.8888 - val_loss: 0.6013 - val_accuracy: 0.7896 - val_precision: 0.8227 - val_recall: 0.7609
# Epoch 66/100
# 50/50 [==============================] - 193s 4s/step - loss: 0.2629 - accuracy: 0.9059 - precision: 0.9316 - recall: 0.8842 - val_loss: 0.6329 - val_accuracy: 0.7978 - val_precision: 0.8287 - val_recall: 0.7732
# Epoch 67/100
# 50/50 [==============================] - 175s 4s/step - loss: 0.2423 - accuracy: 0.9160 - precision: 0.9389 - recall: 0.8995 - val_loss: 0.6230 - val_accuracy: 0.7978 - val_precision: 0.8271 - val_recall: 0.7582
# Epoch 68/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2529 - accuracy: 0.9125 - precision: 0.9293 - recall: 0.8875 - val_loss: 0.6266 - val_accuracy: 0.7978 - val_precision: 0.8358 - val_recall: 0.7787
# Epoch 69/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.2349 - accuracy: 0.9250 - precision: 0.9489 - recall: 0.9050 - val_loss: 0.5913 - val_accuracy: 0.8074 - val_precision: 0.8382 - val_recall: 0.7855
# Epoch 70/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.2389 - accuracy: 0.9225 - precision: 0.9346 - recall: 0.8925 - val_loss: 0.5809 - val_accuracy: 0.8128 - val_precision: 0.8331 - val_recall: 0.7705
# Epoch 71/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.2157 - accuracy: 0.9389 - precision: 0.9460 - recall: 0.9135 - val_loss: 0.6081 - val_accuracy: 0.7992 - val_precision: 0.8171 - val_recall: 0.7691
# Epoch 72/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2047 - accuracy: 0.9287 - precision: 0.9501 - recall: 0.9038 - val_loss: 0.6230 - val_accuracy: 0.8060 - val_precision: 0.8394 - val_recall: 0.7855
# Epoch 73/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.2132 - accuracy: 0.9225 - precision: 0.9403 - recall: 0.9050 - val_loss: 0.6131 - val_accuracy: 0.7978 - val_precision: 0.8297 - val_recall: 0.7719
# Epoch 74/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.2296 - accuracy: 0.9288 - precision: 0.9441 - recall: 0.9033 - val_loss: 0.6121 - val_accuracy: 0.8019 - val_precision: 0.8336 - val_recall: 0.7732
# Epoch 75/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2102 - accuracy: 0.9287 - precision: 0.9474 - recall: 0.9013 - val_loss: 0.6763 - val_accuracy: 0.7896 - val_precision: 0.8063 - val_recall: 0.7732
# Epoch 76/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2412 - accuracy: 0.9000 - precision: 0.9233 - recall: 0.8875 - val_loss: 0.6001 - val_accuracy: 0.7964 - val_precision: 0.8324 - val_recall: 0.7732
# Epoch 77/100
# 50/50 [==============================] - 145s 3s/step - loss: 0.2060 - accuracy: 0.9362 - precision: 0.9492 - recall: 0.9100 - val_loss: 0.6130 - val_accuracy: 0.8019 - val_precision: 0.8242 - val_recall: 0.7814
# Epoch 78/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.1895 - accuracy: 0.9312 - precision: 0.9496 - recall: 0.9187 - val_loss: 0.5980 - val_accuracy: 0.7951 - val_precision: 0.8175 - val_recall: 0.7773
# Epoch 79/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.2243 - accuracy: 0.9187 - precision: 0.9413 - recall: 0.9013 - val_loss: 0.6093 - val_accuracy: 0.7992 - val_precision: 0.8157 - val_recall: 0.7801
# Epoch 80/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2093 - accuracy: 0.9312 - precision: 0.9481 - recall: 0.9125 - val_loss: 0.6297 - val_accuracy: 0.7978 - val_precision: 0.8227 - val_recall: 0.7732
# Epoch 81/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.2173 - accuracy: 0.9350 - precision: 0.9569 - recall: 0.9150 - val_loss: 0.6350 - val_accuracy: 0.7869 - val_precision: 0.8131 - val_recall: 0.7609
# Epoch 82/100
# 50/50 [==============================] - 139s 3s/step - loss: 0.2038 - accuracy: 0.9211 - precision: 0.9427 - recall: 0.9008 - val_loss: 0.6228 - val_accuracy: 0.8074 - val_precision: 0.8285 - val_recall: 0.7787
# Epoch 83/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.1812 - accuracy: 0.9325 - precision: 0.9548 - recall: 0.9237 - val_loss: 0.6037 - val_accuracy: 0.8033 - val_precision: 0.8416 - val_recall: 0.7842
# Epoch 84/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.1984 - accuracy: 0.9350 - precision: 0.9558 - recall: 0.9187 - val_loss: 0.6125 - val_accuracy: 0.8087 - val_precision: 0.8309 - val_recall: 0.7855
# Epoch 85/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.1726 - accuracy: 0.9438 - precision: 0.9598 - recall: 0.9250 - val_loss: 0.6282 - val_accuracy: 0.8005 - val_precision: 0.8166 - val_recall: 0.7787
# Epoch 86/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.2112 - accuracy: 0.9287 - precision: 0.9380 - recall: 0.9075 - val_loss: 0.6198 - val_accuracy: 0.7978 - val_precision: 0.8220 - val_recall: 0.7760
# Epoch 87/100
# 50/50 [==============================] - 143s 3s/step - loss: 0.1995 - accuracy: 0.9350 - precision: 0.9453 - recall: 0.9075 - val_loss: 0.6187 - val_accuracy: 0.8060 - val_precision: 0.8280 - val_recall: 0.7828
# Epoch 88/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.1918 - accuracy: 0.9300 - precision: 0.9431 - recall: 0.9112 - val_loss: 0.6299 - val_accuracy: 0.8019 - val_precision: 0.8283 - val_recall: 0.7910
# Epoch 89/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.1751 - accuracy: 0.9375 - precision: 0.9521 - recall: 0.9200 - val_loss: 0.6083 - val_accuracy: 0.8128 - val_precision: 0.8254 - val_recall: 0.7814
# Epoch 90/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.1599 - accuracy: 0.9529 - precision: 0.9637 - recall: 0.9453 - val_loss: 0.6443 - val_accuracy: 0.7964 - val_precision: 0.8076 - val_recall: 0.7801
# Epoch 91/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.1761 - accuracy: 0.9351 - precision: 0.9411 - recall: 0.9148 - val_loss: 0.6378 - val_accuracy: 0.7978 - val_precision: 0.8177 - val_recall: 0.7842
# Epoch 92/100
# 50/50 [==============================] - 141s 3s/step - loss: 0.1808 - accuracy: 0.9488 - precision: 0.9574 - recall: 0.9262 - val_loss: 0.6188 - val_accuracy: 0.8005 - val_precision: 0.8209 - val_recall: 0.7828
# Epoch 93/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.1774 - accuracy: 0.9351 - precision: 0.9551 - recall: 0.9198 - val_loss: 0.6145 - val_accuracy: 0.8074 - val_precision: 0.8326 - val_recall: 0.7814
# Epoch 94/100
# 50/50 [==============================] - 130s 3s/step - loss: 0.1778 - accuracy: 0.9413 - precision: 0.9547 - recall: 0.9225 - val_loss: 0.6079 - val_accuracy: 0.8074 - val_precision: 0.8380 - val_recall: 0.7842
# Epoch 95/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.1738 - accuracy: 0.9425 - precision: 0.9596 - recall: 0.9212 - val_loss: 0.6268 - val_accuracy: 0.7923 - val_precision: 0.8163 - val_recall: 0.7650
# Epoch 96/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.1721 - accuracy: 0.9388 - precision: 0.9548 - recall: 0.9250 - val_loss: 0.6449 - val_accuracy: 0.7896 - val_precision: 0.8062 - val_recall: 0.7787
# Epoch 97/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.1423 - accuracy: 0.9538 - precision: 0.9642 - recall: 0.9425 - val_loss: 0.6483 - val_accuracy: 0.7951 - val_precision: 0.8166 - val_recall: 0.7787
# Epoch 98/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.1518 - accuracy: 0.9491 - precision: 0.9574 - recall: 0.9427 - val_loss: 0.6210 - val_accuracy: 0.8033 - val_precision: 0.8163 - val_recall: 0.7951
# Epoch 99/100
# 50/50 [==============================] - 140s 3s/step - loss: 0.1672 - accuracy: 0.9513 - precision: 0.9664 - recall: 0.9337 - val_loss: 0.6222 - val_accuracy: 0.7937 - val_precision: 0.8177 - val_recall: 0.7719
# Epoch 100/100
# 50/50 [==============================] - 142s 3s/step - loss: 0.1850 - accuracy: 0.9453 - precision: 0.9531 - recall: 0.9313 - val_loss: 0.6144 - val_accuracy: 0.8046 - val_precision: 0.8248 - val_recall: 0.7910

# %%
model5.save('model/testing/modelmobile_1(1).h5')

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(test3.history[met])
    ax[i].plot(test3.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
plt.savefig("model/Moduul6/modelmobile.svg")

# %% [markdown]
# # Feature Extractor

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

# %%
class FeatureExtractor:
    def __init__(self, model):
        self.model = model
    
    def extract(self, img):
        img = img.resize((224, 224))
        img = img.convert('RGB')
        
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        
        feature = self.model.predict(x)[0]
        
        return feature / np.linalg.norm(feature)

fe = FeatureExtractor(load_model('model/testing/modelmobile_1(1).h5', compile=False))

# %%
from pathlib import Path
from PIL import Image
from tensorflow.keras.preprocessing import image
base_dir = 'Test/img2'
feature_dir = 'Test/feature_extract/1/'

img_paths = list()
features = list()

for img_path in sorted(Path(base_dir).glob("*.jpg")):
    img_paths.append(img_path)
    feature = fe.extract(img=Image.open(img_path))
    features.append(feature)

features = np.array(features)
np.save(feature_dir + '/extracted_feature+.npy', features)

# %% [markdown]
# # Uji Coba

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

query_image = img_paths[224]
img = Image.open(query_image)

query = fe.extract(img)

dists = np.linalg.norm(features - query, axis=1)

# Extract 9 images that have lowest distance
ids = np.argsort(dists)[:9]
scores = [(dists[id], img_paths[id]) for id in ids]

# Visualize the result
axes = list()
fig = plt.figure(figsize=(8,8))

for a in range(3 * 3):
    axes.append(fig.add_subplot(3, 3, a+1))

    score = scores[a]

    nama_citra = os.path.basename(score[1])

    subplot_title = str(score[0]) + f"\n{nama_citra}"
    axes[-1].set_title(subplot_title)  

    plt.axis('off')
    plt.imshow(Image.open(score[1]))

fig.tight_layout()
plt.show()

# %% [markdown]
# # Evaluasi

# %% [markdown]
# Percobaan pertama

# %%
#test
loss, acc, prec, rec = model5.evaluate(valid_generator)
print(f"Accuracy = {acc * 100:.2f} %")
print(f"Precision = {prec * 100:.2f} %")
print(f"Recall = {rec * 100:.2f} %")
# Out:
# 46/46 [==============================] - 71s 2s/step - loss: 0.6109 - accuracy: 0.8142 - precision: 0.8345 - recall: 0.7992
# Accuracy = 81.42 %
# Precision = 83.45 %
# Recall = 79.92 %

# %% [markdown]
# Percobaan kedua

# %%
#test
loss, acc, prec, rec = model5.evaluate(valid_generator)
print(f"Accuracy = {acc * 100:.2f} %")
print(f"Precision = {prec * 100:.2f} %")
print(f"Recall = {rec * 100:.2f} %")
# Out:
# 46/46 [==============================] - 76s 2s/step - loss: 0.6244 - accuracy: 0.7978 - precision: 0.8197 - recall: 0.7828
# Accuracy = 79.78 %
# Precision = 81.97 %
# Recall = 78.28 %

# %% [markdown]
# # LINK

# %% [markdown]
# **Link HeroKu dan Github**
# * Heroku : https://cbirtkc1.herokuapp.com/
# * Github : https://github.com/Marlianur09/diabetic-cbir-project-heroku-main
